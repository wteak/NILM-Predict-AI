# %%
import pyarrow as pa
import lightgbm as lgb# lgb명칭으로 lightgbm외부라이브워리 불러옴
import pvlib#태양광 발전 전문 태양 위치 등
import pandas as pd
import numpy as np
import dask as dd

print("pyarrow가 설치되었으며 버전은:", pa.__version__)
print("pvlib가 설치되었으며 버전은:", pvlib.__version__)
print("pandas가 설치되었으며 버전은:", pd.__version__)
print("lightgbm이 설치되었으며 버전은:", lgb.__version__)
print("numpy가 설치되었으며 버전은:", np.__version__)
print("dask가 설치되었으며 버전은:", dd.__version__)

# %%
import pandas as pd
import numpy as np
file_path = '홈에너지_시간별_계측.csv' 
df = pd.read_csv(file_path)
print(f" 데이터 요약 정보")
print("="*60)
print(f"{df.shape[0]} 행, {df.shape[1]} 열")
print("-"*60)
print(" [변수 리스트]:")
print(df.columns.tolist())
print("-"*60)
pd.set_option('display.max_columns', None) 
pd.set_option('display.width', 1000)
print(df.head())
# Out:
#  데이터 요약 정보
# ============================================================
# 26196995 행, 16 열
# ------------------------------------------------------------
#  [변수 리스트]:
# ['LGL_CD', 'BLCK_CD', 'BUILDING_CD', 'ROOM_CD', 'READ_YMD', 'READ_HHMI', 'ELEC_ACCUM', 'ELEC_INTER', 'GAS_ACCUM', 'GAS_INTER', 'WTR_ACCUM', 'WTR_INTER', 'HEAT_ACCUM', 'HEAT_INTER', 'HOTWTR_ACCUM', 'HOTWTR_INTER']
# ------------------------------------------------------------
#    LGL_CD BLCK_CD  BUILDING_CD  ROOM_CD  READ_YMD  READ_HHMI  ELEC_ACCUM  ELEC_INTER  GAS_ACCUM  GAS_INTER  WTR_ACCUM  WTR_INTER  HEAT_ACCUM  HEAT_INTER  HOTWTR_ACCUM  HOTWTR_INTER
# 0   11500    MG04          403     1303  20250101          0     39095.0         0.1       0.30        0.0    1629.40        0.0       37.48         0.0        582.50           0.0
# 1   11500    MG04          403     1304  20250101          0     40306.0         0.2       0.40        0.0    1374.00        0.0        6.78         0.0        793.20           0.0
# 2   11500    MG04          403     1401  20250101          0     24323.5         0.2       0.10        0.0    1110.00        0.0       32.63         0.0        424.70           0.0
# 3   11500    MG04          403     1402  20250101          0     49419.1         0.7      28.90        0.0    1627.30        0.0        5.20         0.0        865.60           0.0
# 4   11500    MG09          903     1003  20250101          0     11986.2         0.5     220.18        0.0     490.21        0.0       10.13         0.0        291.28           0.0
