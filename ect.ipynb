# %%
import pyarrow as pa
import lightgbm as lgb# lgb명칭으로 lightgbm외부라이브워리 불러옴
import pvlib#태양광 발전 전문 태양 위치 등
import pandas as pd
import numpy as np
import dask as dd

print("pyarrow가 설치되었으며 버전은:", pa.__version__)
print("pvlib가 설치되었으며 버전은:", pvlib.__version__)
print("pandas가 설치되었으며 버전은:", pd.__version__)
print("lightgbm이 설치되었으며 버전은:", lgb.__version__)
print("numpy가 설치되었으며 버전은:", np.__version__)
print("dask가 설치되었으며 버전은:", dd.__version__)

# %%
import pandas as pd
import numpy as np
file_path = 'H001_ch01_20230922.csv'
df = pd.read_csv(file_path)
print(f" 데이터 요약 정보")
print("="*60)
print(f"{df.shape[0]} 행, {df.shape[1]} 열")
print("-"*60)
print(" [변수 리스트]:")
print(df.columns.tolist())
print("-"*60)
pd.set_option('display.max_columns', None) 
pd.set_option('display.width', 1000)
print(df.head())
# Out:
#  데이터 요약 정보
# ============================================================
# 2592000 행, 11 열
# ------------------------------------------------------------
#  [변수 리스트]:
# ['date_time', 'active_power', 'voltage', 'current', 'frequency', 'apparent_power', 'reactive_power', 'power_factor', 'phase_difference', 'current_phase', 'voltage_phase']
# ------------------------------------------------------------
#                  date_time  active_power  voltage  current  frequency  apparent_power  reactive_power  power_factor  phase_difference  current_phase  voltage_phase
# 0  2023-09-22 00:00:00.000        255.33    217.0    2.018       60.0          437.91          355.76         0.583             150.1          150.1            0.0
# 1  2023-09-22 00:00:00.033        254.19    217.0    2.013       60.0          436.89          355.34         0.582             150.5          150.5            0.0
# 2  2023-09-22 00:00:00.067        253.05    217.0    2.009       60.0          435.88          354.91         0.581             151.0          151.0            0.0
# 3  2023-09-22 00:00:00.100        251.91    217.0    2.004       60.0          434.87          354.47         0.579             151.5          151.5            0.0
# 4  2023-09-22 00:00:00.133        251.97    217.0    2.004       60.0          434.80          354.34         0.580             151.4          151.4            0.0
